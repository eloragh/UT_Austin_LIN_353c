# %% [markdown]
# # LIN 353C: Introduction to Computational Linguistics,  Fall 2020, Erk
#
# # Homework 2: Loops, dictionaries, and language models
#
# ## Due: Tuesday September 21, 3pm right before class
#
# ## Your name: Eloragh Espie
# ## Your EID: eae2273
#
# This homework comes with the following files:
#
# * Introcl_homework_2.ipynb: this notebook, which has the homework problems. **Please put your answers into this same notebook.**
#
#
# Please record all your answers in the appropriate place in this notebook, and **do not forget to put your name and EID at the top of this notebook**.
#
# For the part of the homework that requires you to write Python code,
# we need to see the code.
# You can omit statements that
# produced an error or that did not form part of the eventual solution,
# but please include all the Python code that formed part of your
# solution.
#
# Please use comments to explain what your code does. Any code that seems complicated to you, or goes on for more than 2 lines, can probably use a comment. Just practice commenting more than you think the code needs. As you will see once you pull out an old piece of code you wrote and try to figure out what you were doing, code always needs more comments than you think.
#
# ### Important note: Before you do anything else, please hit the fast-forward button on this notebook, and confirm "Restart and Run all cells", so the code included in this notebook will be executed on your machine.
#
#
# **If any of these instructions do not make sense to you, please get in
#  touch with the instructor right away.**
#
#
# A perfect solution to this homework will be worth *100* points.

# %% [markdown]
# # Problem 1: Punctuation, with loops (10 pts.)
#
#
# Here is a text passage from H.G. Wells, *The War of the Worlds* (from Project Gutenberg, http://www.gutenberg.org/etext/36):

# %%
wellstext = """After the glimpse I had had of the Martians emerging 
from the cylinder in which they had come to the earth 
from their planet, a kind of fascination paralysed my actions.  
I remained standing knee-deep in the heather, staring at the 
mound that hid them.  I was a battleground of fear and curiosity.

I did not dare to go back towards the pit, but I felt a passionate
longing to peer into it.  I began walking, therefore, in a big curve,
seeking some point of vantage and continually looking at the sand
heaps that hid these new-comers to our earth.  Once a leash of thin
black whips, like the arms of an octopus, flashed across the sunset
and was immediately withdrawn, and afterwards a thin rod rose up,
joint by joint, bearing at its apex a circular disk that spun with a
wobbling motion.  What could be going on there?"""

# %% [markdown]
# For this problem, please remove punctuation from beginnings and ends of words in the passage, but do not use regular expressions. Instead, please proceed as follows:
#
# * Please split the passage into words using Python's ```split()```. Do not use NLTK's ```word_tokenize()```, as that already does the work of removing punctuation for you. *(If there is already a tool to do this work for you, why should you practice how to do it by hand? For example because ```word_tokenize()``` may not work equally well for all languages, or because you may want to design a better ```word_tokenize()```.)*
#
# * Then run a for-loop over the list of words, and use Python's ```strip()``` method to remove punctuation. You will need to give `strip()` an appropriate parameter to do this. Collect the resulting list of words without punctuation in a separate list. (That is, use the "aggregation" programming idiom that we discussed in class.) You do not need to keep the punctuation in a separate string. For this problem please just You do not need to remove punctuation from the middle of strings, that is, you do not need to transform the string ``new-comers'' in any way.
#
# Here is information about the method ```strip()```: https://docs.python.org/3.8/library/stdtypes.html#str
#
# Also note that Python has a string full of punctuation symbols that might be useful for this problem:

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# Here is the box for your punctuation removal code:

# %%
# place your code here

punc = string.punctuation

wellstext_list = wellstext.split()

lst = []

for word in wellstext_list:
    lst.append(word.strip(punc))

lst
# Out:
# ['After',
#  'the',
#  'glimpse',
#  'I',
#  'had',
#  'had',
#  'of',
#  'the',
#  'Martians',
#  'emerging',
#  'from',
#  'the',
#  'cylinder',
#  'in',
#  'which',
#  'they',
#  'had',
#  'come',
#  'to',
#  'the',
#  'earth',
#  'from',
#  'their',
#  'planet',
#  'a',
#  'kind',
#  'of',
#  'fascination',
#  'paralysed',
#  'my',
#  'actions',
#  'I',
#  'remained',
#  'standing',
#  'knee-deep',
#  'in',
#  'the',
#  'heather',
#  'staring',
#  'at',
#  'the',
#  'mound',
#  'that',
#  'hid',
#  'them',
#  'I',
#  'was',
#  'a',
#  'battleground',
#  'of',
#  'fear',
#  'and',
#  'curiosity',
#  'I',
#  'did',
#  'not',
#  'dare',
#  'to',
#  'go',
#  'back',
#  'towards',
#  'the',
#  'pit',
#  'but',
#  'I',
#  'felt',
#  'a',
#  'passionate',
#  'longing',
#  'to',
#  'peer',
#  'into',
#  'it',
#  'I',
#  'began',
#  'walking',
#  'therefore',
#  'in',
#  'a',
#  'big',
#  'curve',
#  'seeking',
#  'some',
#  'point',
#  'of',
#  'vantage',
#  'and',
#  'continually',
#  'looking',
#  'at',
#  'the',
#  'sand',
#  'heaps',
#  'that',
#  'hid',
#  'these',
#  'new-comers',
#  'to',
#  'our',
#  'earth',
#  'Once',
#  'a',
#  'leash',
#  'of',
#  'thin',
#  'black',
#  'whips',
#  'like',
#  'the',
#  'arms',
#  'of',
#  'an',
#  'octopus',
#  'flashed',
#  'across',
#  'the',
#  'sunset',
#  'and',
#  'was',
#  'immediately',
#  'withdrawn',
#  'and',
#  'afterwards',
#  'a',
#  'thin',
#  'rod',
#  'rose',
#  'up',
#  'joint',
#  'by',
#  'joint',
#  'bearing',
#  'at',
#  'its',
#  'apex',
#  'a',
#  'circular',
#  'disk',
#  'that',
#  'spun',
#  'with',
#  'a',
#  'wobbling',
#  'motion',
#  'What',
#  'could',
#  'be',
#  'going',
#  'on',
#  'there']

# %% [markdown]
# # Problem 2: Stemming, with loops (15 pts.)
#
# In the previous homework, you used regular expressions and word boundaries, \\b, for stemming. We now revisit stemming, but split the text into a word list first and then iterate over the members of the word list. We'll use the same text passage as before:

# %%
lewistext = """And Peter with his sword still drawn in his hand went with 
the Lion to the eastern edge of the hill-top.  There a beautiful 
sight met their eyes.  The sun was setting behind their backs.  
That meant that the whole country below them lay in the evening 
light--forest and hills and valleys and, winding away like a 
silver snake, the lower part of the great river.  And beyond 
all this, miles away, was the sea, and beyond
the sea the sky, full of clouds which were just turning rose colour
with the reflection of the sunset.  But just where the land of Narnia
met the sea--in fact, at the mouth of the great river--there was
something on a little hill, shining.  It was shining because it was a
castle and of course the sunlight was reflected from all the windows
which looked towards Peter and the sunset; but to Peter it looked like
a great star resting on the seashore."""

# %% [markdown]
# For this problem, please perform stemming on this text, as follows:
#
# * Split the text into words, this time using ```nltk.word_tokenize()```. This will split off the punctuation into separate strings. The result is a list of words.
#
# * Iterate over the words in the list, perform stemming on each one (or leave it the same): Please remove word endings that are "ing", "ed", "ion", or "s" -- see options below. Put the resulting string in a new list. After the for-loop, the result should be a list of words exactly as long as the original word list, but stemmed. So this is another instance of the "aggregation" programming idiom we discussed in class.
#
# You have different options for how to identify word endings: You can use either ```endswith()```, or ```re.search()```. If you use ```re.search()```, note that the end of the word is now the end of the string, so you can use the anchor ```$``` instead of ```\b```.
#
# You also have different options for removing endings: You can use string slices, or you can use ```re.sub()```.

# %%
# put your code here

import nltk
import re

lewistext_list = nltk.word_tokenize(lewistext)

stemmed_list = []

for word in lewistext_list:
    if re.search(r"(ing|ed|ion|s)$", word):
        word = re.sub(r"([A-Za-z]*)(ing|ed|ion|s)$", r"\1", word)
        stemmed_list.append(word)
    else:
        stemmed_list.append(word)

print(len(stemmed_list), len(lewistext_list))
# Out:
# 182 182

# %% [markdown]
# # Problem 3: Building an n-gram language model (20 pts.)
#
# For this problem, you will build an n-gram language model. Use `MLE` from `nltk.lm`, as in the notebook "n-gram language models with NLTK."
#
# Please proceed as follows:
# * Choose a particular book from which to build the language model: For this, go to Project Gutenberg, https://www.gutenberg.org/, and choose a book. Then download *the plain-text version* of the book.
# * Do the whole following pipeline twice, once for **bigram** language models and once for **trigram** language models. Each time, for n-grams of length n:
#   * Use padding, as appropriate for n-grams of length n.
#   * Compute "everygrams" up to lenght n, that is, use n-grams substituted with shorter n-grams.
#   * Train an nltk `MLE` language model.
#   * Use it to produce 100 words. (You can do this last step several times, and you will get new results each time. You can do this to explore your language model.)
#
# In the text box below the code box, please comment on your result. How did the bigram model compare to the trigram model? How specific was the generated text to the style of the book you chose? Also please paste into your text answer your favorite text produced by your bigram, and your favorite text produced by your trigram.

# %%
# bigram model

import nltk
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE

f = open("the_medea.txt")
medea = f.read()
f.close()

medea_sents = nltk.sent_tokenize(medea)

medea_sents_tokenized = [nltk.word_tokenize(s) for s in medea_sents]

medea_corpus, vocab = padded_everygram_pipeline(2, medea_sents_tokenized)

lm_medea = MLE(2)

lm_medea.fit(medea_corpus, vocab)

for word in lm_medea.generate(100):
    print(word, end = " ")
# Out:
# <s> MEDEA . </s> couldst thou see your state law was a great debt for the rites over sundering seas , Yet I not to her , to shield in paragraph 1.E below ; a _dea ex machinâ_ . </s> innumerable to save her for the drama is a woman ; and evil men rejoice . </s> landless women block our fingers Could wake and he hath a bride to find some other gods as a break their giving : and donations can not possible in Norse sagas , May break must go so . </s> , How can not

# %%
# trigram model

import nltk
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE

f = open("the_medea_copy.txt")
medea1 = f.read()
f.close()

medea_sents = nltk.sent_tokenize(medea1)

medea_sents_tokenized = [nltk.word_tokenize(s) for s in medea_sents]

medea_corpus, vocab = padded_everygram_pipeline(3, medea_sents_tokenized)

lm_medea = MLE(3)

lm_medea.fit(medea_corpus, vocab)

for sentno in range(12):
    words =  lm_medea.generate(100)
    
    for w in words:
        if w == "</s>":
            break
        else:
            print(w, end = " ")
# Out:
# the high Sun , Sire of my pains ! would kill me ? , Ye be not , And many a maid In Hellas , now ! <s> <s> Jason doth forsake My mistress in her eye , as some old pilot goes Furled to his daughter 's room , where Hera by the fire not stab my brain ? Thy marriage drive Medea from his land , and They that walk in blood . she gathers them passionately into her arms._ Oh , 't was thy father to unmake His doom of exile on them -- for thy sake , Then sword in hand , And dread her ! shaft of riven pine in Pêlion 's glen Shaped that first oar-blade in the acres of corn . Why hast thou Of children be fulfilled of God . . An eastern dreamer ; one Of brand not theirs ; one Of brand not theirs ; one Of brand not theirs ; one Of brand not theirs ; one hard to play upon . . call Thy curse on these ?

# %% [markdown]
# *space for your text answer here*
#
# Neither text was very coherent, but I think the trigram sentences made more sense overall. From a distance, the bigram text looks like a regular paragraph, but the flow of the sentences and any potential "subject" is lost very quickly. The trigram model also loses the subject, but it seems to do so slower and less abruptly.
#
# I chose the Medea and the generated text was very similar to the style of the play. Each block of generated text looked like something that could be in a Greek tragedy.
#
# My favorite text from the bigram is:
#
#  *"betray , Faith that which , Came with knowledge of hate me.*"
#
# My favorite text from the trigram is an excerpt that I saved from what it generated once. I made the joke that it was babbling a story about "tragic greek tax fraud":
#
# *“Gods or mortals one alone , Where the tears ran over : A Play . common it is important to maintaining tax exempt status by the Sun”*
#
# It's clear that the part about taxes had to do with the text added by Project Gutenburg, but it definitely made me laugh.

# %% [markdown]
# # General information for all the following problems
#
# ## Part-of-speech tags, POS tags for short
#
# Part-of-speech tagging means labeling words in a text as "this is a noun", "this is a verb", "this is a preposition", and so on. There are some texts that have been manually labeled (by human annotators) with POS-tags, among them the Brown corpus (see below). Automatic POS-tagging is an important NLP task.
#
# Usually, the POS-tags we see used are more fine-grained than just "this is a verb" versus "this is a noun", they may distinguish, for example, nouns in singular and plural ("house" versus "houses"), and verbs in base form, 3rd person singular, and past tense ("stroll", "strolls", "strolled").
#
# Here is a list of the POS-tags we will use in the following homework problems: https://en.wikipedia.org/wiki/Brown_Corpus#Part-of-speech_tags_used
#
# ## Accessing the POS-tagged Brown corpus
#
# The Brown corpus is a collection of text pieces from different domains, selected to be about balanced in size across different text types. It comprises about 1 million words. Here is more information on the Brown corpus: https://en.wikipedia.org/wiki/Brown_Corpus
#
# In this and the following problems
# you will use the *news* part of the Brown Corpus in the Natural
# Language Toolkit, more precisely a version of this corpus with
# part-of-speech tags (POS tags). In order to do that, you will need to
# install the NLTK data (if you have not done this already). Do this as follows:
#
#     import nltk
#     nltk.download()
# Then follow the further instructions at http://www.nltk.org/data
#
# Afterwards, you can access the POS-tagged *news* part of the Brown Corpus as follows:

# %%
import nltk
brown_news = nltk.corpus.brown.tagged_words(categories="news")

brown_news[:10]
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN')]

# %% [markdown]
# This gives you a list of tuples, to  be more precise a list of
# pairs. The first member of each pair is a word, and the second member
# is its part-of-speech tag.
#
# A tuple in Python is almost the same as a list: It is a sequence of
# items, and it is written like a list, except with round brackets instead of straight brackets. You can access an item using its index, as in

# %%
mytuple = ('The', 'AT')
mytuple[1]
# Out:
# 'AT'

# %% [markdown]
# The one difference is that you cannot change a tuple, so for example
# you cannot use ```append()``` on it.
#
# For all problems below, please map all words to lowercase in order not to distinguish "The" and "the". You can use the method ```lower()``` for this, as in:

# %%
"The".lower()
# Out:
# 'the'

# %% [markdown]
# # Problem 4: Word frequency and tag frequency, with Python dictionaries (30 pts.)
#
#  What is the most frequent word, and what is the most frequent POS-tag in the *news* section of Brown?
#
#  Do *not* use the NLTK data structures ```nltk.FreqDist```
# and ```nltk.ConditionalFreqDist```, or the Python data type
# ```Counter```, for this problem. Just use Python dictionaries,
#   along with the built-in function ```sorted()```:
#
#   * Make a dictionary to keep counts of words.
#   * Iterate through the list of word/tag pairs. Extract the word from the pair, and use a Python dictionary to keep count of how often you meet each word.
#   * Now make a dictionary to keep counts of tags. Iterate through the list of word/tag pairs again, but this time extract the tags and count them.
#   * Use ```sorted()``` to sort each dictionary by its values, and find the entries with the highest values.
#
#
# This is similar to the exercise we did in class where, for each
# word appearing in a paragraph from *The Onion*, we counted how often
# it appeared.

# %%
# place your code here
import nltk
brown_news = nltk.corpus.brown.tagged_words(categories="news")

word_dict = {}
pos_dict = {}

for tuple in brown_news:
    word = tuple[0].lower()

    if word not in word_dict:
        word_dict[word] = 1
    else:
        word_dict[word] += 1

for tuple in brown_news:
    pos = tuple[1]

    if pos not in pos_dict:
        pos_dict[pos] = 1
    else:
        pos_dict[pos] += 1

pos_dict = sorted(pos_dict.items(), key = lambda x: x[1], reverse = True)

word_dict = sorted(word_dict.items(), key = lambda x: x[1], reverse = True)

non_fd_freq = pos_dict[0], word_dict[0]

print(non_fd_freq)
# Out:
# (('NN', 13162), ('the', 6386))

# %% [markdown]
# # Problem 5: Word frequency and tag frequency, with NLTK's FreqDist (10 pts.)
#
# Please re-do the task from problem 4, but this time use the NLTK ```FreqDist``` data type: What is the most frequent word, and what is the most frequent POS-tag in the *news* section of Brown? This time, create one ```nltk.FreqDist``` object for counts of words, and one for counts of tags. Then use the FreqDist method ```max()``` to determine the most frequent word and the most frequent tag. (Please make sure you get the same answer as before.)

# %%
# please place your code here
import nltk

brown_words = []
brown_pos = []

for tuple in brown_news:
    word = tuple[0].lower()
    brown_words.append(word)

for tuple in brown_news:
    pos = tuple[1]
    brown_pos.append(pos)

word_fd = nltk.FreqDist(brown_words)
pos_fd = nltk.FreqDist(brown_pos)

fd_freq = (pos_fd.most_common(1), word_fd.most_common(1))

print(fd_freq)
# Out:
# ([('NN', 13162)], [('the', 6386)])

# %% [markdown]
# # Problem 6: Ambiguous words, with Python dictionaries (15 pts.)
#
# In this problem, you will use nltk's ``ConditionalFreqDist`` to determine which words in the Brown news corpus have multiple different tags: How many words are ambiguous, in the sense that they appear with at least two different POS tags? For example, the English word "object" is ambiguous in that it could be either a verb or a noun (though I do not know if it occurs in the Brown news corpus as both a verb and a noun).
#
# To solve this problem, build an nltk ``ConditionalFreqDist`` from word/tag pairs *again only using the news part of the Brown corpus*.  You can see an example of a `ConditionalFreqDist` object in the notebook on n-gram language models. Here is another example:

# %%
import nltk

pairs = [ ("a", "X"), ("a", "Y"), ("b", "X"), ("c", "Y")]

# this makes a ConditionalFreqDist object
cd = nltk.ConditionalFreqDist(pairs)
cd
# Out:
# <ConditionalFreqDist with 3 conditions>

# %%
# All the different values seen as first of a pair are conditions
cd.conditions()
# Out:
# ['a', 'b', 'c']

# %%
# the entry for "a" is all the second-of-a-pair entries seen with "a".
# It is a FreqDist object
cd["a"]
# Out:
# FreqDist({'X': 1, 'Y': 1})

# %%
# So we have a complex data type: 
# A ConditionalFreqDist contains many FreqDist objects,
# one for each condition.
# You can save the FreqDist for "a" in a variable.
fda = cd["a"]
# Then all the methods that come with a FreqDist
# are available with that object, for example
# the method tabulate(), which pretty-prints
# all the counts. (This is not the method you need,
# it is just a demonstration of some FreqDist method.)
fda.tabulate()
# Out:
# X Y
# 1 1

# %%
# Space for your code to solve the problem
import nltk

brown_news = nltk.corpus.brown.tagged_words(categories="news")

cfd = nltk.ConditionalFreqDist(brown_news)

#this dictionary will hold the ambiguous words and the assignments provided by the cfd
cfd_ambg = {}

#iterates through each word in brown_news
for tuple in brown_news:
    word = tuple[0]

    #len of cfd objects seem to be based on the number of POS assignments, so I used that
    #to determine if a word was ambiguous
    if len(cfd[word]) > 1:
        cfd_ambg[word] = [key for key in cfd[word].keys()]

print(len(cfd), len(cfd_ambg))

#~12% of words in this corpus are ambiguous
print(format(len(cfd_ambg)/len(cfd), ".2%"))

#dict of ambiguous words and their pos assignments
cfd_ambg
# Out:
# 14394 1723
# 11.97%
# {'The': ['AT', 'AT-TL', 'AT-HL'],
#  'Fulton': ['NP-TL', 'NP'],
#  'Grand': ['JJ-TL', 'FW-JJ-TL'],
#  'said': ['VBD', 'VBN'],
#  'of': ['IN', 'IN-TL', 'IN-HL'],
#  'primary': ['NN', 'JJ'],
#  'produced': ['VBD', 'VBN'],
#  'no': ['AT', 'RB'],
#  'that': ['CS', 'WPS', 'DT', 'QL', 'WPO'],
#  'place': ['NN', 'VB'],
#  '.': ['.', '.-HL'],
#  'jury': ['NN', 'NN-HL'],
#  'further': ['RBR', 'JJR', 'VB'],
#  'in': ['IN', 'RP', 'IN-HL', 'IN-TL'],
#  'the': ['AT', 'AT-TL', 'AT-HL'],
#  'City': ['NN-TL', 'NN', 'NN-TL-HL'],
#  'Executive': ['JJ-TL', 'NN-TL'],
#  'Committee': ['NN-TL', 'NN'],
#  ',': [',', ',-HL'],
#  'had': ['HVD', 'HVN', 'HVD-HL'],
#  'charge': ['NN', 'VB'],
#  'and': ['CC', 'CC-TL', 'CC-HL'],
#  'thanks': ['NNS', 'NNS-HL'],
#  'Atlanta': ['NP-TL', 'NP'],
#  'for': ['IN', 'IN-TL', 'IN-HL', 'CS', 'RB'],
#  'was': ['BEDZ', 'BEDZ-HL'],
#  'conducted': ['VBN', 'VBD'],
#  'charged': ['VBN', 'VBD', 'VBN-HL'],
#  'by': ['IN', 'IN-HL', 'IN-TL', 'RB'],
#  'Court': ['NN-TL', 'NN-HL'],
#  'to': ['TO', 'IN', 'IN-HL', 'TO-HL', 'IN-TL', 'NPS'],
#  'reports': ['NNS', 'VBZ'],
#  'won': ['VBN', 'VBD'],
#  'Only': ['RB', 'AP'],
#  'a': ['AT', 'AT-HL', 'FW-IN'],
#  'such': ['JJ', 'ABL', 'QL'],
#  'received': ['VBN', 'VBD'],
#  'considering': ['IN', 'VBG'],
#  'number': ['NN', 'NN-HL'],
#  'size': ['NN', 'VB'],
#  'this': ['DT', 'DT-HL'],
#  'it': ['PPS', 'PPO'],
#  'are': ['BER', 'BER-HL'],
#  'recommended': ['VBD', 'VBN'],
#  'act': ['VB', 'NN', 'NN-HL'],
#  'studied': ['VBN', 'VBD', 'VBN-HL'],
#  'revised': ['VBN', 'VBD'],
#  'end': ['NN', 'VB'],
#  'commented': ['VBD', 'VBN'],
#  'on': ['IN', 'IN-TL', 'RP', 'IN-HL'],
#  'purchasing': ['VBG', 'NN'],
#  'well': ['QL', 'RB', 'JJ'],
#  'operated': ['VBN', 'VBD'],
#  'accepted': ['VBN', 'VBD'],
#  'practices': ['NNS', 'VBZ'],
#  'best': ['JJT', 'RBT', 'JJT-HL', 'VB'],
#  'proposed': ['VBN-HL', 'VBN', 'VBD'],
#  'However': ['WRB', 'WQL', 'RB'],
#  'be': ['BE', 'BE-HL'],
#  'combined': ['VBN', 'VBD'],
#  'cost': ['NN', 'VB', 'VBD'],
#  'is': ['BEZ', 'BEZ-HL'],
#  'lacking': ['VBG', 'VBG-HL'],
#  'as': ['CS', 'QL', 'CS-HL', 'IN'],
#  'result': ['NN', 'VB'],
#  'urged': ['VBD', 'VBN-HL', 'VBN'],
#  'problem': ['NN', 'NN-HL'],
#  'next': ['AP', 'IN', 'QL'],
#  'funds': ['NNS', 'NNS-HL'],
#  'date': ['NN', 'VB'],
#  'so': ['CS', 'QL', 'RB'],
#  'at': ['IN', 'IN-HL', 'IN-TL'],
#  'State': ['NN-TL', 'NN'],
#  'handling': ['NN', 'VBG'],
#  'welfare': ['NN', 'NN-HL'],
#  'one': ['CD', 'PN'],
#  'major': ['JJ', 'NN'],
#  'general': ['JJ', 'NN'],
#  'program': ['NN', 'VB'],
#  'but': ['CC', 'IN'],
#  'fit': ['JJ', 'VB', 'VBN'],
#  'through': ['IN', 'RP'],
#  'all': ['ABN', 'QL'],
#  'state': ['NN', 'VB'],
#  'with': ['IN', 'IN-HL'],
#  'might': ['MD', 'NN'],
#  'less': ['QL', 'AP', 'RBR'],
#  'feel': ['VB', 'NN'],
#  'future': ['NN', 'JJ', 'NN-HL'],
#  'some': ['DTI', 'DTI-HL'],
#  'do': ['DO', 'DO-HL'],
#  'will': ['MD', 'MD-HL', 'NN'],
#  'court': ['NN', 'NN-TL'],
#  'under': ['IN', 'RB'],
#  'fees': ['NNS', 'NNS-HL'],
#  'found': ['VBD', 'VBN'],
#  'into': ['IN', 'IN-HL'],
#  'effect': ['NN', 'VB'],
#  'from': ['IN', 'IN-HL'],
#  'costs': ['NNS', 'VBZ'],
#  'appointed': ['VBN', 'VBD'],
#  'elected': ['VBN', 'VBD', 'VBN-HL'],
#  'new': ['JJ', 'JJ-HL'],
#  'Jan.': ['NP', 'NP-HL'],
#  '1': ['CD', 'CD-HL', 'CD-TL'],
#  'not': ['*', '*-HL'],
#  'added': ['VBD', 'VBN', 'VBN-HL'],
#  'there': ['EX', 'RB', 'RB-HL'],
#  'pricing': ['VBG', 'NN'],
#  'jail': ['NN-HL', 'NN'],
#  'deputies': ['NNS-HL', 'NNS'],
#  ':': [':', ':-HL'],
#  '(': ['(', '(-HL'],
#  ')': [')', ')-HL'],
#  'Four': ['CD', 'CD-HL', 'CD-TL'],
#  '2': ['CD', 'CD-TL', 'CD-HL'],
#  'work': ['VB', 'NN'],
#  'pass': ['VB', 'NN'],
#  'permit': ['VB', 'NN'],
#  'fair': ['JJ', 'NN', 'JJ-HL'],
#  'plan': ['NN', 'VB', 'NN-HL'],
#  'Police': ['NNS-TL', 'NNS', 'NNS-HL'],
#  'Grady': ['NP-TL', 'NP'],
#  'Hospital': ['NN-TL', 'NN'],
#  'Mayor': ['NN-TL', 'NN-TL-HL'],
#  'William': ['NP', 'NP-TL'],
#  'B.': ['NP', 'NP-TL'],
#  'filed': ['VBD', 'VBN'],
#  'divorce': ['NN', 'VB'],
#  'his': ['PP$', 'PP$$'],
#  'son': ['NN', 'NN-HL'],
#  'Mrs.': ['NP', 'NP-HL'],
#  'J.': ['NP', 'NP-TL'],
#  'agreed': ['VBN', 'VBD'],
#  'upon': ['RB', 'IN'],
#  'listed': ['VBD', 'VBN'],
#  'Ala.': ['NP', 'NP-HL'],
#  'lived': ['VBN', 'VBD'],
#  'more': ['AP', 'QL', 'RBR'],
#  'than': ['IN', 'CS'],
#  'year': ['NN', 'NN-HL'],
#  'home': ['NR', 'NN', 'NN-HL', 'NR-HL'],
#  'E.': ['NP', 'NP-HL', 'JJ-TL'],
#  'since': ['IN', 'CS', 'RB'],
#  'back': ['RB', 'VB', 'NN', 'RB-HL'],
#  'present': ['JJ', 'RB', 'NN', 'VB'],
#  'succeeded': ['VBN', 'VBD'],
#  'after': ['CS', 'IN'],
#  'announced': ['VBD', 'VBN'],
#  'would': ['MD', 'MD-HL'],
#  'run': ['VB', 'NN', 'VBN'],
#  'Georgia': ['NP', 'NP-TL', 'NP-HL'],
#  'Republicans': ['NPS', 'NPS-HL'],
#  'race': ['NN', 'VB'],
#  'top': ['JJS', 'NN', 'VB'],
#  'official': ['NN', 'JJ'],
#  'GOP': ['NN', 'NN-HL'],
#  'meeting': ['NN', 'VBG'],
#  'held': ['VBN', 'VBD', 'VBN-HL'],
#  'Blue': ['JJ-TL', 'JJ'],
#  'brought': ['VBD', 'VBN'],
#  'Party': ['NN-TL', 'NN'],
#  'James': ['NP', 'NP-TL'],
#  'W.': ['NP', 'NP-HL'],
#  'up': ['RP', 'RP-HL', 'IN'],
#  '8': ['CD', 'CD-TL'],
#  'newly': ['RB', 'JJ'],
#  'Texas': ['NP', 'NP-HL', 'NP-TL'],
#  'John': ['NP', 'NP-HL', 'NP-TL'],
#  'In': ['IN', 'IN-TL'],
#  'warned': ['VBN', 'VBD'],
#  'force': ['VB', 'NN'],
#  'petitions': ['NNS', 'VBZ'],
#  'out': ['RP', 'IN', 'PP$', 'RP-HL'],
#  'warning': ['VBG', 'NN'],
#  'vote': ['NN', 'VB'],
#  'attended': ['VBD', 'VBN'],
#  'asked': ['VBN', 'VBD', 'VBN-HL'],
#  'wanted': ['VBD', 'VBN'],
#  'wait': ['VB', 'NN'],
#  'face': ['VB', 'NN'],
#  'before': ['CS', 'IN', 'RB'],
#  'making': ['VBG', 'NN'],
#  'first': ['OD', 'RB', 'OD-HL'],
#  'alternative': ['JJ', 'NN'],
#  'must': ['MD', 'NN'],
#  'Five': ['CD', 'CD-HL'],
#  'county': ['NN', 'NN-TL'],
#  'sign': ['VB', 'NN'],
#  'allowed': ['VBN', 'VBD'],
#  'hold': ['VB', 'NN'],
#  'party': ['NN', 'NN-HL'],
#  'public': ['JJ', 'NN'],
#  'relations': ['NNS', 'NNS-HL'],
#  'campaign': ['NN', 'VB'],
#  'expected': ['VBN', 'VBN-HL', 'VBD'],
#  'assistant': ['NN', 'JJ'],
#  'three': ['CD', 'CD-HL'],
#  'years': ['NNS', 'NNS-HL'],
#  'starts': ['VBZ', 'NNS'],
#  'become': ['VB', 'VBN'],
#  'wind': ['VB', 'NN'],
#  'head': ['VB', 'NN', 'JJS'],
#  'approved': ['VBD', 'VBN'],
#  'Before': ['IN', 'CS'],
#  'study': ['NN', 'VB'],
#  'allotted': ['VBN', 'VBD'],
#  'made': ['VBN', 'VBD', 'VBN-HL'],
#  'visit': ['NN', 'VB'],
#  'likely': ['RB', 'JJ'],
#  'issue': ['NN', 'VB', 'NN-HL'],
#  'earlier': ['RBR', 'JJR'],
#  'Construction': ['NN-HL', 'NN'],
#  'bonds': ['NNS-HL', 'NNS'],
#  'learned': ['VBN', 'VBD'],
#  'very': ['QL', 'AP'],
#  'near': ['RB', 'RB-HL', 'JJ', 'IN', 'QL'],
#  'worth': ['NN', 'JJ'],
#  'go': ['VB', 'NN'],
#  'test': ['NN', 'VB'],
#  'contracts': ['NNS', 'VBZ'],
#  'let': ['VBN', 'VB'],
#  'most': ['QL', 'AP', 'RBT'],
#  'heavily': ['RB', 'QL'],
#  'traveled': ['VBN', 'VBD'],
#  'A': ['AT', 'AT-HL', 'NN', 'AT-TL'],
#  'revolving': ['VBG-HL', 'VBG'],
#  'fund': ['NN-HL', 'NN'],
#  'issued': ['VBN', 'VBD'],
#  'paid': ['VBN', 'VBD'],
#  'off': ['RP', 'IN', 'RP-HL'],
#  'tax': ['NN', 'VB'],
#  'opened': ['VBD', 'VBN'],
#  'against': ['IN', 'IN-TL'],
#  'roads': ['NNS', 'NNS-HL'],
#  'told': ['VBD', 'VBN'],
#  'consulted': ['VBN', 'VBN-HL'],
#  'yet': ['RB', 'CC'],
#  'about': ['IN', 'RB', 'RP'],
#  'plans': ['NNS', 'NNS-HL', 'VBZ'],
#  'offer': ['VB', 'NN'],
#  'House': ['NN-TL', 'NP-TL-HL', 'NP', 'NN-TL-HL'],
#  'increase': ['NN', 'VB', 'VB-HL'],
#  'research': ['NN', 'NN-HL'],
#  'outright': ['RB', 'JJ'],
#  'notice': ['NN', 'VB'],
#  'sought': ['VBN', 'VBD', 'VBN-HL'],
#  'worked': ['VBN', 'VBD'],
#  'set': ['VB', 'VBN', 'VBD', 'VBN-HL', 'NN'],
#  'passed': ['VBD', 'VBN'],
#  'As': ['IN', 'CS', 'QL'],
#  'offered': ['VBN', 'VBD'],
#  'last': ['AP', 'VB', 'NN', 'AP-HL'],
#  'rejected': ['VBD', 'VBN'],
#  'pay': ['NN', 'VB', 'VB-HL'],
#  'veteran': ['JJ', 'NN'],
#  'Jackson': ['NP-TL', 'NP', 'NP-HL'],
#  'aid': ['NN', 'VB'],
#  'opposed': ['VBN', 'VBD'],
#  'past': ['NN', 'JJ', 'AP', 'IN'],
#  'Barber': ['NP', 'NN-HL'],
#  'increased': ['VBN', 'VBD'],
#  'support': ['NN', 'VB', 'NN-HL'],
#  'provided': ['VBN', 'VBD'],
#  'Washington': ['NP', 'NP-HL', 'NP-TL'],
#  'like': ['VB', 'CS', 'IN', 'JJ', 'VB-HL'],
#  'read': ['VBN', 'VBD', 'VB'],
#  'Congress': ['NP', 'NP-HL'],
#  'Board': ['NN-TL', 'NN', 'NN-HL'],
#  'Education': ['NN-TL', 'NN'],
#  'directed': ['VBN', 'VBD'],
#  'Colquitt': ['NP-HL', 'NP-TL'],
#  'After': ['IN', 'CS'],
#  'long': ['JJ', 'RB'],
#  'Miller': ['NP-TL', 'NP'],
#  'put': ['VBD', 'VB', 'VBN'],
#  'I': ['PPSS', 'NN'],
#  'saw': ['VBD', 'VB'],
#  'defeated': ['VBD', 'VBN'],
#  'principal': ['NN', 'JJS'],
#  'Democratic': ['JJ-TL', 'JJ'],
#  'votes': ['NNS', 'VBZ'],
#  'got': ['VBD', 'VBN'],
#  'Carey': ['NP', 'NP-HL'],
#  'order': ['NN', 'VB'],
#  'just': ['RB', 'JJ', 'QL'],
#  'church': ['NN', 'NN-HL'],
#  'drop': ['NN', 'VB'],
#  'bit': ['NN', 'VBD'],
#  'calls': ['NNS', 'VBZ', 'VBZ-HL'],
#  'P.': ['NP', 'NN-TL'],
#  'shot': ['VBD', 'NN', 'VBN'],
#  'March': ['NP', 'NP-HL', 'NN-TL'],
#  '18': ['CD', 'CD-HL'],
#  'days': ['NNS', 'NNS-HL'],
#  'post': ['NN', 'VB'],
#  'too': ['RB', 'QL'],
#  'scheduled': ['VBD', 'VBN'],
#  'Many': ['AP', 'AP-HL'],
#  'local': ['JJ', 'NN'],
#  'ordinary': ['NN', 'JJ'],
#  'good': ['JJ', 'NN', 'RB', 'JJ-HL'],
#  'promise': ['NN', 'VB'],
#  'real': ['QL', 'JJ'],
#  'There': ['EX', 'RB'],
#  'Austin': ['NP-HL', 'NP'],
#  'Price': ['NP', 'NN'],
#  'abandoned': ['VBN', 'VBD'],
#  'led': ['VBD', 'VBN'],
#  'fight': ['NN', 'NN-HL', 'VB'],
#  'measure': ['NN', 'VB'],
#  'down': ['RP', 'IN', 'RP-HL'],
#  'considerably': ['RB', 'QL'],
#  'hearing': ['NN', 'NN-HL', 'VBG'],
#  'Revenue': ['NN-TL', 'NN-HL'],
#  'Under': ['IN', 'JJ-TL'],
#  'rules': ['NNS', 'NNS-HL'],
#  'week': ['NN', 'NN-HL'],
#  'left': ['VBD', 'VBN', 'JJ', 'NR'],
#  'little': ['AP', 'JJ', 'QL'],
#  'doubt': ['NN', 'NN-HL'],
#  'termed': ['VBD', 'VBN', 'VBN-HL'],
#  'extremely': ['RB', 'QL'],
#  'estimate': ['NN', 'VB'],
#  '17': ['CD', 'CD-HL'],
#  'help': ['VB', 'NN', 'NN-HL', 'VB-HL'],
#  'merely': ['RB', 'QL'],
#  'means': ['NNS', 'VBZ'],
#  'permits': ['VBZ', 'NNS'],
#  'over': ['RP', 'IN', 'IN-HL'],
#  'stocks': ['NNS', 'NNS-HL'],
#  'seven': ['CD', 'CD-HL'],
#  'report': ['VB', 'NN', 'VB-HL'],
#  'because': ['CS', 'RB'],
#  'almost': ['RB', 'QL'],
#  'declared': ['VBD', 'VBN'],
#  'Lawrence': ['NP', 'NP-TL'],
#  'keynote': ['NN', 'VB'],
#  'you': ['PPSS', 'PPO'],
#  'Charles': ['NP', 'NP-TL'],
#  'Hughes': ['NP', 'NP-TL'],
#  'Sherman': ['NP', 'NP-TL'],
#  'sponsor': ['NN', 'VB'],
#  'amount': ['VB', 'NN'],
#  'denied': ['VBN', 'VBD'],
#  'Jones': ['NP', 'NP-HL', 'NP-TL'],
#  'Howard': ['NP', 'NP-TL'],
#  'argued': ['VBD', 'VBN'],
#  'enough': ['AP', 'AP-HL', 'QLP'],
#  'introduced': ['VBN', 'VBD'],
#  'only': ['RB', 'AP', 'JJ', 'QL'],
#  'Senators': ['NNS', 'NNS-TL'],
#  'Dallas': ['NP', 'NP-TL', 'NP-HL'],
#  'schools': ['NNS', 'NNS-HL'],
#  'special': ['JJ', 'JJ-HL'],
#  'schooling': ['NN', 'VBG'],
#  'reduced': ['VBN', 'VBD'],
#  'attend': ['VB', 'VB-HL'],
#  'here': ['RB', 'RB-HL'],
#  'five': ['CD', 'CD-HL'],
#  'Harris': ['NP', 'NP-TL', 'NP-HL'],
#  'estimated': ['VBD', 'VBN-HL', 'VBN'],
#  'live': ['VB', 'JJ'],
#  'Red': ['NP', 'JJ-TL', 'NN-TL'],
#  'still': ['RB', 'QL'],
#  'pro': ['JJ', 'NN', 'IN'],
#  'betting': ['NN', 'VBG'],
#  'better': ['RBR', 'VB', 'JJR', 'QL'],
#  'informed': ['VBN', 'VBD'],
#  'question': ['NN', 'VB'],
#  'San': ['NP', 'NP-HL'],
#  'heard': ['VBD', 'VBN'],
#  'proposal': ['NN', 'NN-HL'],
#  'faces': ['VBZ', 'NNS', 'NNS-HL'],
#  'hard': ['JJ', 'RB'],
#  'later': ['RBR', 'JJR'],
#  'house': ['NN', 'NN-HL', 'VB'],
#  'sent': ['VBD', 'VBN'],
#  'planning': ['VBG', 'NN'],
#  'senate': ['NN', 'NN-HL'],
#  'One': ['CD', 'CD-TL', 'PN'],
#  'Beaumont': ['NP-TL', 'NP'],
#  'third': ['OD', 'RB'],
#  'Lamar': ['NP-TL', 'NP'],
#  'adopted': ['VBN', 'VBN-HL'],
#  'R.': ['NP', 'NP-HL'],
#  'Two': ['CD', 'CD-HL', 'CD-TL'],
#  'Louis': ['NP', 'NP-TL'],
#  'return': ['NN', 'VB'],
#  'fine': ['NN', 'JJ', 'RB'],
#  'Research': ['NN-TL', 'NN'],
#  'Paris': ['NP', 'NP-HL', 'NP-TL'],
#  'own': ['JJ', 'VB'],
#  'license': ['NN', 'VB'],
#  'gas': ['NN', 'VB'],
#  'right': ['NN', 'JJ', 'RB', 'QL'],
#  '3': ['CD-TL', 'CD', 'CD-HL', 'OD', 'OD-TL'],
#  'underground': ['JJ', 'RB'],
#  'Marshall': ['NP', 'NP-TL'],
#  'suggested': ['VBD', 'JJ'],
#  'need': ['NN', 'VB', 'MD'],
#  'selected': ['VBN', 'VBD'],
#  'chief': ['JJS', 'NN'],
#  'decided': ['VBD', 'VBN'],
#  'taking': ['VBG', 'NN'],
#  'kind': ['NN', 'JJ'],
#  'kept': ['VBD', 'VBN', 'VBD-HL'],
#  'April': ['NP', 'NP-HL'],
#  '4': ['CD', 'CD-TL'],
#  'U.S.': ['NP', 'NP-TL', 'NP-HL'],
#  'delay': ['NN', 'VB'],
#  'West': ['JJ-TL', 'NR-TL'],
#  'reported': ['VBD', 'VBN', 'VBN-HL'],
#  'Feb.': ['NP', 'NP-HL'],
#  '22': ['CD', 'CD-TL'],
#  'two-thirds': ['NNS', 'NN'],
#  'All': ['ABN', 'ABN-HL'],
#  'lost': ['VBD', 'VBN'],
#  'water': ['NN', 'VB'],
#  'needs': ['NNS', 'VBZ'],
#  'big': ['JJ', 'JJ-HL'],
#  'Fort': ['NN-TL', 'NN-TL-HL'],
#  'cover': ['VB', 'NN'],
#  'places': ['NNS', 'NNS-HL'],
#  'ended': ['VBD', 'VBN'],
#  'sponsored': ['VBN', 'VBD'],
#  'Most': ['AP', 'QL-TL'],
#  'maximum': ['JJ', 'NN'],
#  'project': ['NN', 'VB'],
#  'felt': ['VBD', 'VBN'],
#  'spent': ['VBN', 'VBD'],
#  'providing': ['VBG', 'CS'],
#  'benefit': ['VB', 'NN'],
#  'attack': ['NN', 'VB', 'NN-HL'],
#  'De': ['NP', 'FW-IN', 'FW-IN-TL'],
#  'La': ['NP', 'FW-AT-TL'],
#  'serving': ['VBG', 'NN'],
#  'learning': ['VBG', 'NN'],
#  'C.': ['NP', 'NP-TL'],
#  '24': ['CD', 'CD-HL'],
#  '12': ['CD', 'CD-TL'],
#  'teaching': ['VBG', 'NN'],
#  'required': ['VBN', 'VBD'],
#  'junior': ['JJ', 'NN'],
#  'senior': ['JJ', 'NN'],
#  'high': ['JJ', 'NN', 'JJ-HL', 'RB'],
#  'credit': ['VB', 'NN'],
#  'English': ['NP', 'JJ'],
#  'permitted': ['VBN', 'VBD'],
#  'College': ['NN', 'NN-TL'],
#  'joined': ['VBD', 'VBN'],
#  'named': ['VBN', 'VBD'],
#  'Dr.': ['NN-TL', 'NN-TL-HL'],
#  'close': ['NN', 'JJ', 'RB', 'VB'],
#  'earned': ['VBN', 'VBD'],
#  'Oklahoma': ['NP-TL', 'NP'],
#  '&': ['CC', 'CC-TL', 'CC-HL'],
#  'Southwestern': ['JJ-TL', 'JJ'],
#  'Massachusetts': ['NP-TL', 'NP'],
#  'served': ['VBN', 'VBD', 'VBD-HL'],
#  'High': ['JJ-TL', 'JJ'],
#  'associate': ['JJ', 'VB'],
#  'Denton': ['NP-HL', 'NP-TL', 'NP'],
#  'Chester': ['NP', 'NP-TL'],
#  'O.': ['NP', 'NP-TL'],
#  'called': ['VBN', 'VBD'],
#  'Cook': ['NP', 'NP-TL'],
#  'New': ['JJ-TL', 'JJ-HL', 'JJ'],
#  'firm': ['NN', 'JJ'],
#  '10': ['CD', 'CD-TL'],
#  'range': ['NN', 'NN-HL'],
#  'case': ['NN', 'NN-HL'],
#  'causes': ['NNS', 'VBZ'],
#  'Must': ['MD-HL', 'MD', 'MD-TL'],
#  'solve': ['VB-HL', 'VB'],
#  'We': ['PPSS', 'PPSS-HL'],
#  'forced': ['VBN', 'VBD'],
#  'cases': ['NNS', 'NNS-HL'],
#  'deal': ['VB', 'VB-HL'],
#  'limited': ['VBN', 'VBD'],
#  'extension': ['NN-HL', 'NN'],
#  'Other': ['AP', 'AP-HL'],
#  'living': ['VBG', 'NN'],
#  'police': ['NN', 'NNS', 'NNS-HL'],
#  'trial': ['NN', 'NN-HL'],
#  'viewed': ['VBN', 'VBD'],
#  'grant': ['VB', 'NN', 'VB-HL'],
#  'request': ['NN', 'VB'],
#  'while': ['CS', 'NN', 'VB'],
#  'prejudicial': ['JJ-HL', 'JJ'],
#  'aspects': ['NNS-HL', 'NNS'],
#  'Some': ['DTI', 'DTI-HL'],
#  'indicated': ['VBD', 'VBN'],
#  'others': ['NNS', 'NNS-HL'],
#  'honor': ['NN', 'VB', 'VB-HL'],
#  'amounts': ['VBZ', 'NNS'],
#  'conflict': ['NN', 'VB'],
#  'July': ['NP-HL', 'NP'],
#  'President': ['NN-TL', 'NN'],
#  'Kennedy': ['NP', 'NP-TL'],
#  'pushed': ['VBD', 'VBN'],
#  'White': ['JJ-TL', 'NN-TL', 'NP'],
#  'business': ['NN', 'NN-HL'],
#  'Berlin': ['NP', 'NP-TL'],
#  'tomorrow': ['NR', 'NR-HL'],
#  'American': ['JJ', 'JJ-TL', 'NP'],
#  'much': ['AP', 'QL', 'RB'],
#  'writing': ['VBG', 'NN'],
#  'talked': ['VBD', 'VBN'],
#  'Chief': ['JJS-TL', 'NN-TL', 'JJS'],
#  'returned': ['VBD', 'VBN'],
#  'quite': ['ABL', 'QL', 'RB'],
#  'way': ['NN', 'QL'],
#  'Asked': ['VBN', 'VBD'],
#  'Pierre': ['NP', 'NP-TL'],
#  'press': ['NN', 'VB'],
#  "it's": ['PPS+HVZ', 'PPS+BEZ'],
#  'staff': ['NN', 'VB'],
#  'involved': ['VBD', 'VBN', 'VBN-HL'],
#  'wording': ['VBG', 'NN'],
#  'rather': ['IN', 'RB'],
#  'meet': ['VB', 'VB-HL', 'NN'],
#  'Acting': ['VBG-TL', 'VBG'],
#  'obtained': ['VBD', 'VBN'],
#  'matter': ['NN', 'VB'],
#  'even': ['QL', 'RB', 'JJ', 'VB'],
#  'ruled': ['VBD', 'VBN'],
#  '133': ['CD', 'CD-TL'],
#  'Morris': ['NP', 'NP-TL'],
#  'admitted': ['VBD', 'VBN'],
#  'questioned': ['VBD', 'VBN'],
#  'building': ['NN', 'VBG'],
#  'constituted': ['VBD', 'VBN'],
#  'used': ['VBN', 'VBD'],
#  'outside': ['IN', 'JJ', 'NN'],
#  'judge': ['NN', 'VB'],
#  'East': ['JJ-TL', 'NR-TL'],
#  'St.': ['NP-TL', 'NN-TL', 'NP', 'NP-HL'],
#  '24th': ['OD', 'OD-TL'],
#  'precedent': ['NN-HL', 'NN'],
#  'reading': ['VBG', 'NN', 'NN-HL'],
#  '9': ['CD-HL', 'CD', 'CD-TL'],
#  'care': ['NN', 'NN-HL', 'VB'],
#  'raised': ['VBN', 'VBN-HL', 'VBD'],
#  'covered': ['VBN', 'VBD'],
#  'tied': ['VBD', 'VBN'],
#  'requests': ['NNS', 'VBZ'],
#  'finance': ['VB', 'NN'],
#  'hill': ['NN-TL', 'NN-HL', 'NN'],
#  '$37': ['NNS-HL', 'NNS'],
#  'boost': ['VB', 'NN'],
#  'rise': ['VB', 'NN'],
#  'figures': ['NNS', 'VBZ'],
#  'higher': ['RBR', 'JJR', 'JJR-HL'],
#  'payment': ['NN', 'NN-HL'],
#  'patient': ['NN', 'JJ'],
#  'nursing': ['VBG', 'VBG-HL'],
#  'following': ['VBG', 'NN'],
#  'use': ['VB', 'NN'],
#  'noted': ['VBD', 'VBN'],
#  'modest': ['JJ-HL', 'JJ'],
#  'wish': ['NN', 'VB'],
#  'staggered': ['VBN', 'VBD'],
#  'caused': ['VBN', 'VBD'],
#  'stay': ['NN', 'VB'],
#  'cut': ['VBN', 'VB', 'VBD', 'NN-HL', 'NN'],
#  'essential': ['JJ', 'NN'],
#  'doctors': ['NNS-HL', 'NNS'],
#  'needed': ['VBN', 'VBN-HL', 'VBD'],
#  'equal': ['JJ', 'VB'],
#  'matching': ['VBG', 'JJ'],
#  'More': ['AP-HL', 'AP'],
#  'field': ['NN', 'VB'],
#  'institute': ['NN', 'VB'],
#  'how': ['QL', 'WRB'],
#  'For': ['IN', 'IN-TL', 'IN-HL', 'CS'],
#  'Congressional': ['JJ', 'JJ-TL'],
#  'along': ['IN', 'RB'],
#  'lines': ['NNS', 'VBZ'],
#  'Legislators': ['NNS', 'NNS-HL'],
#  'criticized': ['VBD', 'VBN-HL', 'VBN'],
#  'hailed': ['VBD', 'VBN-HL'],
#  'Republican': ['NP-TL', 'NP', 'JJ'],
#  'Ill.': ['NP', 'NP-HL'],
#  'change': ['VB', 'NN-HL', 'NN'],
#  'Tex.': ['NP', 'NP-HL'],
#  'mighty': ['QL', 'JJ'],
#  'housing': ['VBG', 'NN'],
#  '11': ['CD', 'CD-HL'],
#  'speed': ['VB', 'NN'],
#  'rule': ['NN', 'VB'],
#  'demand': ['NN-HL', 'NN', 'VB'],
#  'Wayne': ['NP', 'NP-TL'],
#  'Oslo': ['NP-HL', 'NP'],
#  'North': ['JJ-TL', 'NR-TL'],
#  'Atlantic': ['NP-TL', 'JJ-TL', 'JJ'],
#  'Foreign': ['JJ-TL', 'JJ'],
#  'understanding': ['NN', 'VBG'],
#  'route': ['NN', 'FW-NN'],
#  'step': ['NN', 'VB'],
#  'met': ['VBN', 'VBD'],
#  'particularly': ['RB', 'QL'],
#  'powers': ['NNS', 'VBZ'],
#  'Africa': ['NP', 'NP-TL'],
#  'allies': ['NNS', 'NNS-HL'],
#  'troubles': ['NNS', 'NNS-HL'],
#  'walk': ['VB', 'NN'],
#  'Council': ['NN-TL', 'NN'],
#  'General': ['JJ-TL', 'NN-TL'],
#  'discussed': ['VBN', 'VBD'],
#  'advance': ['NN', 'VB'],
#  'Canada': ['NP', 'NP-TL'],
#  'somewhat': ['QL', 'RB'],
#  'behind': ['IN', 'RB'],
#  'daily': ['JJ', 'RB'],
#  'arms': ['NNS', 'NNS-HL'],
#  'closer': ['JJR', 'RBR'],
#  'United': ['VBN-TL', 'VBN-TL-HL'],
#  'hoped': ['VBN', 'VBD'],
#  'Dean': ['NP', 'NN-TL'],
#  'clear': ['JJ', 'VB'],
#  'mood': ['NN-HL', 'NN'],
#  'Soviet': ['NN-TL', 'NP'],
#  'individual': ['JJ', 'NN'],
#  'march': ['NN', 'VB'],
#  'inside': ['IN', 'NN'],
#  'stand': ['VB', 'NN'],
#  'once': ['RB', 'CS'],
#  'again': ['RB', 'RB-HL'],
#  'whole': ['NN', 'JJ'],
#  'surveyed': ['VBN-HL', 'VBN'],
#  'around': ['IN', 'RB'],
#  'treated': ['VBN', 'VBD'],
#  'regard': ['NN', 'VB'],
#  'lack': ['NN', 'VB', 'NN-HL'],
#  'main': ['NN', 'JJS'],
#  'strengthening': ['VBG', 'NN'],
#  'forces': ['NNS', 'VBZ'],
#  'come': ['VB', 'VBN'],
#  'laid': ['VBN', 'VBD'],
#  'completely': ['QL', 'RB'],
#  'fulfilled': ['VBN', 'VBD'],
#  'moves': ['VBZ', 'NNS'],
#  'Geneva': ['NP', 'NP-HL'],
#  'Laos': ['NP', 'NP-TL', 'NP-HL'],
#  'military': ['JJ', 'NN'],
#  'setting': ['VBG', 'NN'],
#  'international': ['JJ', 'NN'],
#  'Viet': ['NP-TL', 'NP'],
#  'Nam': ['NP-TL', 'NP'],
#  'count': ['VB', 'NN'],
#  'hopes': ['VBZ', 'NNS'],
#  'Lao': ['NP-TL', 'NP'],
#  'Policies': ['NNS-HL', 'NNS'],
#  'modified': ['VBN-HL', 'VBN'],
#  'control': ['NN', 'VB'],
#  'showing': ['VBG', 'NN'],
#  'gain': ['NN', 'VB'],
#  'How': ['WRB', 'QL'],
#  'Detroit': ['NP', 'NP-TL'],
#  'tougher': ['JJR', 'RBR'],
#  'restrained': ['VBN-HL', 'VBN'],
#  'hardly': ['RB', 'QL'],
#  'raising': ['VBG', 'NN'],
#  'Cuba': ['NP', 'NP-HL'],
#  'score': ['NN', 'VB'],
#  'reply': ['NN', 'VB'],
#  'Morton': ['NP', 'NP-TL'],
#  'National': ['JJ-TL', 'JJ'],
#  'Boston': ['NP-TL', 'NP-HL', 'NP'],
#  'groups': ['NNS', 'NNS-HL'],
#  'trade': ['NN', 'VB'],
#  'Latin': ['JJ-TL', 'JJ'],
#  'America': ['NP-TL', 'NP'],
#  'Until': ['CS', 'IN'],
#  'Cuban': ['NP', 'JJ'],
#  'voiced': ['VBN', 'VBD'],
#  'revamped': ['VBN-HL', 'VBN'],
#  'early': ['RB', 'JJ'],
#  'disclosed': ['VBD', 'VBN'],
#  'Eisenhower': ['NP', 'NP-TL'],
#  'reviewed': ['VBN', 'VBD'],
#  'changed': ['VBN', 'VBD'],
#  'thus': ['QL', 'RB'],
#  'far': ['RB', 'QL', 'JJ'],
#  'looked': ['VBD', 'VBN'],
#  'show': ['VB', 'NN', 'NN-HL'],
#  'Asian': ['JJ-TL', 'JJ'],
#  'faster': ['JJR', 'RBR'],
#  'rate': ['NN', 'VB'],
#  'And': ['CC', 'CC-TL'],
#  'exposed': ['VBD', 'VBN'],
#  'acclaimed': ['VBD', 'VBN'],
#  'Asia': ['NP-TL', 'NP'],
#  'steamed': ['VBN', 'VBD'],
#  'prepared': ['VBD', 'VBN'],
#  'risk': ['VB', 'NN'],
#  'war': ['NN', 'NN-HL'],
#  'concluded': ['VBN', 'VBD'],
#  'ill': ['QL', 'JJ'],
#  'favor': ['NN', 'VB'],
#  'Royal': ['JJ-TL', 'NP'],
#  '25': ['CD', 'CD-TL'],
#  'erred': ['VBN', 'VBD'],
#  'half': ['ABN', 'RB', 'NN', 'QL'],
#  'encouraging': ['VBG', 'JJ'],
#  'check': ['VB', 'NN'],
#  'juvenile': ['JJ', 'NN'],
#  'deeply': ['QL', 'RB'],
#  'Crime': ['NN-TL', 'NN-HL'],
#  'supported': ['VBN', 'VBD'],
#  'recognized': ['VBN', 'VBD'],
#  'Attorney': ['NN-TL', 'NN'],
#  'Labor': ['NN-TL', 'NN-HL', 'NN'],
#  'assist': ['VB', 'NN'],
#  'David': ['NP', 'NP-TL'],
#  'sense': ['NN', 'VB'],
#  'doubled': ['VBN', 'VBD'],
#  'Federal': ['JJ-TL', 'JJ'],
#  'Providence': ['NP-TL', 'NP'],
#  'handed': ['VBN', 'VBD'],
#  'believed': ['VBD', 'VBN'],
#  'men': ['NNS', 'NNS-HL'],
#  'Along': ['RB', 'IN'],
#  'headquarters': ['NN', 'NNS'],
#  'rescue': ['NN', 'VB'],
#  'bet': ['VB', 'VBD'],
#  'know': ['VB', 'VB-HL'],
#  'point': ['NN', 'NN-HL', 'VB'],
#  'Such': ['JJ', 'ABL'],
#  'call': ['VB', 'NN'],
#  'developed': ['VBN', 'VBD'],
#  'name': ['VB', 'NN'],
#  'move': ['NN', 'VB'],
#  'form': ['NN', 'VB'],
#  'clerk': ['NN', 'VB'],
#  'released': ['VBN', 'VBD'],
#  'complete': ['JJ', 'VB'],
#  'review': ['NN', 'VB'],
#  'Gen.': ['JJ-TL', 'NN-TL'],
#  'views': ['VBZ', 'NNS'],
#  'advised': ['VBN', 'VBD'],
#  'across': ['IN', 'RP', 'IN-HL'],
#  'limit': ['VB', 'NN'],
#  'sold': ['VBN', 'VBD'],
#  'concern': ['NN', 'NN-HL', 'VB'],
#  'especially': ['RB', 'QL'],
#  'placed': ['VBN', 'VBD'],
#  'retained': ['VBN', 'VBD'],
#  'Rotary': ['JJ-TL', 'NP', 'NP-TL'],
#  'average': ['JJ', 'NN'],
#  'pull': ['NN', 'VB'],
#  'Socialist': ['JJ-TL', 'NN-TL'],
#  'That': ['DT', 'CS'],
#  'retired': ['VBD', 'VBN'],
#  'gross': ['JJ', 'NN'],
#  'neither': ['DTX', 'CC'],
#  'wage': ['NN', 'VB'],
#  'caught': ['VBN', 'VBD'],
#  'profit': ['NN', 'VB'],
#  'turned': ['VBN', 'VBD'],
#  'really': ['RB', 'QL'],
#  'counseling': ['NN', 'VBG'],
#  'Johnston': ['NP', 'NP-TL'],
#  'presented': ['VBN', 'VBD'],
#  'hand': ['NN', 'VB'],
#  'explained': ['VBD', 'VBN'],
#  'handled': ['VBN', 'VBD'],
#  'assured': ['VBD', 'VBN'],
#  'correct': ['JJ', 'VB'],
#  'hope': ['VB', 'NN'],
#  'surprised': ['VBN', 'VBD'],
#  'Our': ['PP$', 'PP$-TL'],
#  'followed': ['VBN', 'VBD'],
#  'started': ['VBD', 'VBN'],
#  'speaking': ['VBG', 'NN'],
#  'model': ['JJ', 'NN', 'VB'],
#  'meaning': ['NN', 'VBG'],
#  'cited': ['VBN', 'VBD', 'VBN-HL'],
#  'included': ['VBN', 'VBD'],
#  'Action': ['NN', 'NN-TL'],
#  'minor': ['NN', 'JJ'],
#  'traffic': ['NN', 'NN-HL'],
#  'draft': ['VB', 'NN'],
#  'authorized': ['VBN', 'VBD'],
#  'Nothing': ['PN', 'PN-HL'],
#  'Local': ['JJ', 'NN-TL'],
#  'Plainfield': ['NP-HL', 'NP'],
#  'value': ['NN', 'NN-HL'],
#  'Westfield': ['NP-TL', 'NP'],
#  'Young': ['JJ-TL', 'JJ'],
#  'greeted': ['VBN', 'VBD'],
#  'Trenton': ['NP', 'NP-HL'],
#  'stopped': ['VBD', 'VBN'],
#  "he's": ['PPS+HVZ', 'PPS+BEZ'],
#  'sell': ['VB', 'NN'],
#  'remains': ['NNS', 'VBZ'],
#  'considered': ['VBD', 'VBN'],
#  'fall': ['NN', 'NN-HL'],
#  'common': ['JJ', 'NN'],
#  'either': ['CC', 'DTX'],
#  'open': ['JJ', 'RB', 'VB', 'NN'],
#  'launched': ['VBD', 'VBN'],
#  'Jersey': ['NP-TL', 'NP'],
#  'industry': ['NN', 'NN-HL'],
#  'share': ['VB', 'NN'],
#  'blame': ['NN', 'VB'],
#  'plant': ['NN', 'VB'],
#  'until': ['CS', 'IN'],
#  'saved': ['VBD', 'VBN'],
#  'faced': ['VBN', 'VBD'],
#  'vehicles': ['NNS', 'NNS-HL'],
#  'challenge': ['VB', 'NN'],
#  'stands': ['VBZ', 'NNS'],
#  'Ike': ['NP-HL', 'NP'],
#  'position': ['NN', 'NN-HL'],
#  'ahead': ['RB-HL', 'RB'],
#  'May': ['NP', 'NP-HL'],
#  'gathering': ['NN', 'VBG'],
#  'Case': ['NP', 'NP-TL'],
#  'answer': ['VB', 'NN'],
#  'failed': ['VBD', 'VBN'],
#  'glow': ['NN', 'VB-HL'],
#  'purchase': ['NN', 'VB'],
#  'Appeals': ['NNS-TL', 'NNS'],
#  'filled': ['VBN', 'VBD'],
#  'Conservation': ['NN-TL', 'NN-HL'],
#  'Commissioner': ['NN-TL', 'NN-TL-HL'],
#  'credits': ['VBZ', 'NNS'],
#  'Michigan': ['NP-TL', 'NP'],
#  'established': ['VBD', 'VBN'],
#  'expanded': ['VBD', 'VBN'],
#  'training': ['NN', 'VBG'],
#  'credited': ['VBN', 'VBD'],
#  'co-operative': ['JJ', 'NN'],
#  'bid': ['NN', 'VBD', 'VB'],
#  'nearly': ['RB', 'QL'],
#  'expedient': ['JJ', 'NN'],
#  'win': ['VB', 'NN-HL'],
#  'planned': ['VBN', 'VBN-HL', 'VBD'],
#  'talk': ['VB', 'NN'],
#  'full': ['JJ', 'RB'],
#  'stop': ['NN', 'VB'],
#  'To': ['TO', 'IN', 'TO-TL', 'IN-TL'],
#  'lives': ['VBZ', 'NNS'],
#  'representative': ['JJ', 'NN'],
#  'Green': ['JJ-TL', 'NP'],
#  'land': ['NN', 'VB'],
#  'green': ['JJ', 'NN'],
#  'comment': ['VB', 'NN'],
#  'honored': ['VBN', 'VBD'],
#  'Wagner': ['NP', 'NP-TL'],
#  'Screvane': ['NP', 'NP-HL'],
#  'Beame': ['NP', 'NP-HL'],
#  'regarded': ['VBD', 'VBN'],
#  'Brooklyn': ['NP', 'NP-TL'],
#  '7': ['CD', 'CD-TL', 'CD-HL'],
#  'file': ['NN', 'VB'],
#  'view': ['NN', 'VB'],
#  'Buckley': ['NP', 'NP-HL'],
#  'visits': ['VBZ-HL', 'NNS'],
#  'touch': ['NN', 'VB'],
#  'replaced': ['VBN', 'VBD'],
#  'Last': ['AP', 'AP-TL'],
#  'visited': ['VBD', 'VBN'],
#  'key': ['NN', 'JJS', 'NN-HL'],
#  'talks': ['NNS', 'VBZ'],
#  'assumed': ['VBN', 'VBD'],
#  'Hunter': ['NP-TL', 'NP'],
#  'June': ['NP-HL', 'NP'],
#  '16': ['CD-HL', 'CD'],
#  'feeling': ['NN', 'VBG'],
#  'remarks': ['VBZ', 'NNS'],
#  "It's": ['PPS+BEZ', 'PPS+BEZ-HL'],
#  'influence': ['VB', 'NN'],
#  'object': ['NN', 'VB'],
#  'identified': ['VBN', 'VBD'],
#  'novel': ['NN', 'JJ'],
#  'works': ['NNS', 'VBZ', 'NNS-HL'],
#  'escape': ['VB', 'NN'],
#  'Day': ['NN', 'NN-TL', 'NP'],
#  'Public': ['JJ-TL', 'JJ'],
#  'accused': ['VBN', 'VBD'],
#  'hopeful': ['JJ-HL', 'JJ'],
#  'encounter': ['VB', 'NN', 'NN-HL'],
#  'low': ['JJ', 'RB', 'NN'],
#  'Thomas': ['NP', 'NP-TL'],
#  'Three': ['CD-HL', 'CD'],
#  'carried': ['VBN', 'VBD'],
#  'corps': ['NN', 'FW-NN'],
#  'submitted': ['VBN', 'VBD'],
#  'stage': ['NN', 'VB'],
#  'Six': ['CD', 'CD-HL', 'NP'],
#  'Question': ['NN-HL', 'NN'],
#  'discovered': ['VBD', 'VBN'],
#  'worry': ['VB', 'NN'],
#  'U.': ['NP-TL', 'NN-TL', 'NP'],
#  'S.': ['NP-TL', 'NP', 'JJ-TL'],
#  'Government': ['NN-TL', 'NN'],
#  'explains': ['VBZ-HL', 'VBZ'],
#  "don't": ['DO*', 'DOZ*'],
#  'No': ['AT', 'AT-HL', 'RB', 'AT-TL'],
#  'Moscow': ['NP-HL', 'NP'],
#  'pulled': ['VBD', 'VBN'],
#  '!': ['.', '.-HL'],
#  'allocated': ['VBD', 'VBN'],
#  'beginning': ['NN', 'VBG'],
#  '1954': ['CD', 'CD-HL'],
#  'Nations': ['NNS-TL-HL', 'NNS-TL', 'NNS'],
#  'N.': ['NP-HL', 'JJ-TL', 'NP'],
#  'Y.': ['NP-HL', 'NP'],
#  'filling': ['VBG', 'NN'],
#  'due': ['JJ-HL', 'RB', 'JJ'],
#  'officer': ['NN', 'NN-HL'],
#  'start': ['VB', 'NN'],
#  'above': ['IN', 'JJ', 'RB'],
#  'joint': ['NN', 'JJ'],
#  'Britain': ['NP', 'NP-TL'],
#  'round': ['NN', 'VB', 'JJ'],
#  'pace': ['NN', 'NN-HL'],
#  'slowed': ['VBN', 'VBD'],
#  'reached': ['VBN', 'VBD'],
#  'principles': ['NNS-HL', 'NNS'],
#  'search': ['NN', 'VB'],
#  'commercial': ['NN', 'JJ'],
#  'artist': ['NN', 'NN-HL'],
#  'advertising': ['VBG', 'NN'],
#  'native': ['NN', 'JJ'],
#  'Orleans': ['NP-TL', 'NP'],
#  'Field': ['NN-TL', 'NP'],
#  'Miles': ['NP-TL', 'NP'],
#  'Pennsylvania': ['NP-TL', 'NP'],
#  'parade': ['NN', 'VB'],
#  'mass': ['VB', 'NN'],
#  'Hill': ['NN-TL', 'NP'],
#  'ceremonies': ['NNS', 'NNS-HL'],
#  'ride': ['VB', 'NN'],
#  'impressive': ['JJ', 'JJ-HL'],
#  'approach': ['VB', 'NN'],
#  'buildings': ['NNS-HL', 'NNS'],
#  'Of': ['IN', 'IN-HL', 'IN-TL'],
#  'block': ['NN', 'VB'],
#  'Great': ['JJ', 'JJ-TL'],
#  'recorded': ['VBN', 'VBD'],
#  'watch': ['VB', 'NN'],
#  'square': ['NN-HL', 'NN'],
#  'Street': ['NN', 'NN-TL-HL', 'NN-TL'],
#  'car': ['NN', 'NN-HL'],
#  'opposite': ['IN', 'JJ'],
#  'Battle': ['NN-TL', 'NN-HL'],
#  '40': ['CD', 'CD-TL'],
#  'Division': ['NN', 'NN-TL'],
#  'Then': ['RB', 'JJ'],
#  'headed': ['VBN', 'VBD'],
#  'Force': ['NN-TL', 'FW-NN-TL'],
#  'Miss.': ['NP-HL', 'NP'],
#  'largely': ['RB', 'QL'],
#  'surrounded': ['VBN', 'VBD'],
#  'scramble': ['NN-HL', 'NN'],
#  'iron': ['VB', 'NN'],
#  'throw': ['VB', 'NN'],
#  'honeymoon': ['NN', 'VB'],
#  'Smith': ['NP', 'NP-TL'],
#  'equally': ['RB', 'QL'],
#  'clouded': ['VBN-HL', 'VBN'],
#  'ranks': ['NNS', 'VBZ'],
#  'bypass': ['VB', 'NN'],
#  'flow': ['VB', 'NN'],
#  'remained': ['VBD', 'VBN'],
#  'La.': ['NP-HL', 'NP'],
#  'related': ['VBN', 'VBD'],
#  'cash': ['NN', 'VB'],
#  'weary': ['JJ-HL', 'JJ'],
#  'Indeed': ['QLP', 'RB'],
#  'clearing': ['VBG', 'NN'],
#  'play': ['VB', 'NN'],
#  'toss': ['VB', 'NN'],
#  'frustrated': ['VBN', 'VBD'],
#  'though': ['CS', 'RB'],
#  'continued': ['VBD', 'VBN'],
#  'Since': ['CS', 'IN'],
#  'spending': ['VBG', 'NN'],
#  'blocked': ['VBN', 'VBD'],
#  'trim': ['VB', 'JJ'],
#  'tried': ['VBN', 'VBD'],
#  'bids': ['NNS', 'NNS-HL'],
#  'ranged': ['VBN', 'VBD'],
#  'sued': ['VBN', 'VBD'],
#  'contract': ['NN', 'VB'],
#  'Philadelphia': ['NP-TL', 'NP', 'NP-HL'],
#  'played': ['VBD', 'VBN', 'VBD-HL'],
#  'appeared': ['VBD', 'VBN'],
#  'fired': ['VBN', 'VBD'],
#  'charges': ['NNS', 'VBZ'],
#  'sue': ['VB', 'VB-HL'],
#  'bankrupt': ['JJ-HL', 'JJ'],
#  '2d': ['OD-TL', 'OD'],
#  'draw': ['VB', 'NN'],
#  'Business': ['NN', 'NN-TL'],
#  'claim': ['NN', 'VB'],
#  ...}

# %% [markdown]
# If you have trouble solving this one, read on below.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# To solve this problem, proceed as follows:
# * Make a ConditionalFreqDist from all the word/tag pairs in the Brown news corpus
# * Then use the aggregator programming idiom:
#   * Make an empty variable to store all ambiguous words
#   * Iterate over all the conditions in the ConditionalFreqDist (conditions are words here)
#   * For each condition/word, retrieve its associated FreqDist.
#   * Determine how many different tags there are that have counts in this FreqDist.
#     If you need help remembering which function to use for this, run ```help(nltk.FreqDist)``` in a new code box.
#   * if there is more than one tag that has counts in this FreqDist, store this condition/word in your variable that holds all ambiguous words
